# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\apltk\Downloads\imdb_top_1000.csv')
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.nunique()
# Out:
# Poster_Link      1000
# Series_Title      999
# Released_Year     100
# Certificate        16
# Runtime           140
# Genre             202
# IMDB_Rating        17
# Overview         1000
# Meta_score         63
# Director          548
# Star1             660
# Star2             841
# Star3             891
# Star4             939
# No_of_Votes       999
# Gross             823
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df = df.drop(columns = "Certificate")
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# ...

# %%
df = df.drop(columns = "Poster_Link")
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   object
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Overview       1000 non-null   object
#  6   Meta_score     843 non-null    float64
#  7   Director       1000 non-null   object
#  8   Star1          1000 non-null   object
#  9   Star2          1000 non-null   object
#  10  Star3          1000 non-null   object
#  11  Star4          1000 non-null   object
#  12  No_of_Votes    1000 non-null   int64
#  13  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 109.5+ KB

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
df.loc[1]
# Out:
# Series_Title                                         The Godfather
# Released_Year                                                 1972
# Runtime                                                    175 min
# Genre                                                 Crime, Drama
# IMDB_Rating                                                    9.2
# Overview         An organized crime dynasty's aging patriarch t...
# Meta_score                                                   100.0
# Director                                      Francis Ford Coppola
# Star1                                                Marlon Brando
# Star2                                                    Al Pacino
# Star3                                                   James Caan
# Star4                                                 Diane Keaton
# No_of_Votes                                                1620367
# Gross                                                  134,966,411
# Name: 1, dtype: object

# %%
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# ...

# %%
df["Gross"] = df["Gross"].str.replace('NaN','')
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# ...

# %%
df=df.fillna('')
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama         9.30
# 1                Crime, Drama         9.20
# 2        Action, Crime, Drama         9.00
# 3                Crime, Drama         9.00
# 4                Crime, Drama         9.00
# ..                        ...          ...
# ...

# %%
data.describe().T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data.describe().T
#
# NameError: name 'data' is not defined

# %%
df2=df.groupby('Director')[['Gross']].sum()
df2
# Out:
#                                       Gross
# Director
# Aamir Khan                        1,223,869
# Aaron Sorkin
# Abdellatif Kechiche               2,199,675
# Abhishek Chaubey
# Abhishek Kapoor                   1,122,527
# ...                                     ...
# Zack Snyder          210,614,939107,509,799
# Zaza Urushadze                      144,501
# Zoya Akhtar              3,108,4855,566,534
# Çagan Irmak
# Ömer Faruk Sorak
#
# [548 rows x 1 columns]

# %%
df2.sort_values(by='Gross', ascending=False)
# Out:
#                                                               Gross
# Director
# Buster Keaton                                               977,375
# Steven Spielberg  96,898,818216,540,909248,159,971197,171,806164...
# J.J. Abrams                       936,662,225257,730,019228,778,661
# Majid Majidi                                                933,933
# Cecil B. DeMille                                         93,740,000
# ...                                                             ...
# Mamoru Hosoda
# Martin Rosen
# Masaki Kobayashi
# Matthew Warchus
# Ömer Faruk Sorak
#
# [548 rows x 1 columns]

# %%
pd.set_option('display.max.rows', 548)
df2
# Out:
#                                                                               Gross
# Director
# Aamir Khan                                                                1,223,869
# Aaron Sorkin
# Abdellatif Kechiche                                                       2,199,675
# Abhishek Chaubey
# Abhishek Kapoor                                                           1,122,527
# Adam Elliot
# Adam McKay                                                               70,259,870
# Aditya Chopra
# Aditya Dhar                                                               4,186,168
# Akira Kurosawa                                         269,06155,2404,135,75096,568
# Alain Resnais                                                                88,300
# Alan J. Pakula                                                           70,600,000
# Alan Parker                                          22,244,20734,603,94335,000,000
# ...

# %%
print(df['Gross'].dtype)
# Out:
# object

# %%
df.info
# Out:
# <bound method DataFrame.info of                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama         9.30
# 1                Crime, Drama         9.20
# 2        Action, Crime, Drama         9.00
# 3                Crime, Drama         9.00
# 4                Crime, Drama         9.00
# ...

# %%
df['Gross']
# Out:
# 0      28341469.00
# 1     134966411.00
# 2     534858444.00
# 3      57300000.00
# 4       4360000.00
#           ...
# 995            NaN
# 996            NaN
# 997    30500000.00
# 998            NaN
# 999            NaN
# Name: Gross, Length: 1000, dtype: float64

# %%
df=df.fillna('')
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama         9.30
# 1                Crime, Drama         9.20
# 2        Action, Crime, Drama         9.00
# 3                Crime, Drama         9.00
# 4                Crime, Drama         9.00
# ..                        ...          ...
# ...

# %%
df['Gross'] = pd.to_numeric(df['Gross'], errors='coerce')
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama         9.30
# 1                Crime, Drama         9.20
# 2        Action, Crime, Drama         9.00
# 3                Crime, Drama         9.00
# 4                Crime, Drama         9.00
# ..                        ...          ...
# ...

# %%
df2 = df.groupby('Director')[['Gross']].sum().sort_values(by="Gross",ascending=False)
df2
# Out:
#                                          Gross
# Director
# Steven Spielberg                 2478133165.00
# Anthony Russo                    2205039403.00
# Christopher Nolan                1937454106.00
# James Cameron                    1748236602.00
# Peter Jackson                    1597312443.00
# J.J. Abrams                      1423170905.00
# Brad Bird                        1099627795.00
# Robert Zemeckis                  1049446456.00
# David Yates                       978953721.00
# Pete Docter                       939382131.00
# Ridley Scott                      766711423.00
# Quentin Tarantino                 727034316.00
# James Gunn                        722989701.00
# David Fincher                     713314479.00
# Sam Mendes                        698139284.00
# Joss Whedon                       648794064.00
# Lee Unkrich                       624730895.00
# Todd Phillips                     612773814.00
# Andrew Stanton                    604651425.00
# ...

# %%
df2=df2.groupby('Director')[['Gross']].mean().sort_values(by="Gross",ascending=False)
df2.head(10)
# Out:
#                           Gross
# Director
# Steven Spielberg  2478133165.00
# Anthony Russo     2205039403.00
# Christopher Nolan 1937454106.00
# James Cameron     1748236602.00
# Peter Jackson     1597312443.00
# J.J. Abrams       1423170905.00
# Brad Bird         1099627795.00
# Robert Zemeckis   1049446456.00
# David Yates        978953721.00
# Pete Docter        939382131.00

# %%
df2.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Director'>

# %%
df_steven=df[df['Director'].str.contains('Steven Spielberg')]
df_steven
# Out:
#                            Series_Title Released_Year  Runtime  \
# 7                      Schindler's List          1993  195 min
# 24                  Saving Private Ryan          1998  169 min
# 72              Raiders of the Lost Ark          1981  115 min
# 168  Indiana Jones and the Last Crusade          1989  127 min
# 243                 Catch Me If You Can          2002  141 min
# 262                       Jurassic Park          1993  127 min
# 415                                Jaws          1975  124 min
# 682                    The Color Purple          1985  154 min
# 688          E.T. the Extra-Terrestrial          1982  115 min
# 832                   Empire of the Sun          1987  153 min
# 890                     Bridge of Spies          2015  142 min
# 951                     Minority Report          2002  145 min
# 988  Close Encounters of the Third Kind          1977  138 min
#
#                          Genre  IMDB_Rating  \
# ...

# %%
df_steven2=df_steven.groupby('Series_Title')[['Gross']].mean().sort_values(by='Gross', ascending=False)
df_steven2
# Out:
#                                           Gross
# Series_Title
# E.T. the Extra-Terrestrial         435110554.00
# Jurassic Park                      402453882.00
# Jaws                               260000000.00
# Raiders of the Lost Ark            248159971.00
# Saving Private Ryan                216540909.00
# Indiana Jones and the Last Crusade 197171806.00
# Catch Me If You Can                164615351.00
# Close Encounters of the Third Kind 132088635.00
# Minority Report                    132072926.00
# The Color Purple                    98467863.00
# Schindler's List                    96898818.00
# Bridge of Spies                     72313754.00
# Empire of the Sun                   22238696.00

# %%
df_steven3=df[df['Director'].str.contains('Steven Spielberg')]
df_steven3
# Out:
#                            Series_Title Released_Year  Runtime  \
# 7                      Schindler's List          1993  195 min
# 24                  Saving Private Ryan          1998  169 min
# 72              Raiders of the Lost Ark          1981  115 min
# 168  Indiana Jones and the Last Crusade          1989  127 min
# 243                 Catch Me If You Can          2002  141 min
# 262                       Jurassic Park          1993  127 min
# 415                                Jaws          1975  124 min
# 682                    The Color Purple          1985  154 min
# 688          E.T. the Extra-Terrestrial          1982  115 min
# 832                   Empire of the Sun          1987  153 min
# 890                     Bridge of Spies          2015  142 min
# 951                     Minority Report          2002  145 min
# 988  Close Encounters of the Third Kind          1977  138 min
#
#                          Genre  IMDB_Rating  \
# ...

# %%
df_steven3.groupby('Series_Title')[['Gross','IMDB_Rating']].mean().sort_values(by=['IMDB_Rating','Gross'], ascending=False)
# Out:
#                                           Gross  IMDB_Rating
# Series_Title
# Schindler's List                    96898818.00         8.90
# Saving Private Ryan                216540909.00         8.60
# Raiders of the Lost Ark            248159971.00         8.40
# Indiana Jones and the Last Crusade 197171806.00         8.20
# Jurassic Park                      402453882.00         8.10
# Catch Me If You Can                164615351.00         8.10
# Jaws                               260000000.00         8.00
# E.T. the Extra-Terrestrial         435110554.00         7.80
# The Color Purple                    98467863.00         7.80
# Empire of the Sun                   22238696.00         7.70
# Close Encounters of the Third Kind 132088635.00         7.60
# Minority Report                    132072926.00         7.60
# Bridge of Spies                     72313754.00         7.60

# %%
df5=df.groupby('Released_Year')[['IMDB_Rating']].mean().sort_values(by='IMDB_Rating', ascending=False)
df5.head(15)
# Out:
#                IMDB_Rating
# Released_Year
# 1936                  8.50
# 1921                  8.30
# 1957                  8.28
# 1994                  8.24
# 1942                  8.23
# 1931                  8.20
# 1924                  8.20
# 1927                  8.20
# 1954                  8.17
# 1941                  8.15
# 1950                  8.14
# 2020                  8.13
# 1937                  8.10
# 1920                  8.10
# 1958                  8.10

# %%
df5.plot()
# Out:
# <Axes: xlabel='Released_Year'>

# %%
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama         9.30
# 1                Crime, Drama         9.20
# 2        Action, Crime, Drama         9.00
# 3                Crime, Drama         9.00
# 4                Crime, Drama         9.00
# ..                        ...          ...
# ...

# %%
df6=df.groupby('Genre')[['IMDB_Rating']].mean().sort_values(by='IMDB_Rating', ascending=False)
df6
# Out:
#                                IMDB_Rating
# Genre
# Animation, Drama, War                 8.50
# Drama, Musical                        8.40
# Action, Sci-Fi                        8.40
# Drama, Mystery, War                   8.35
# Western                               8.35
# Crime, Drama, Music                   8.30
# Mystery, Romance, Thriller            8.30
# Adventure, Mystery, Thriller          8.30
# Drama, Fantasy, Horror                8.30
# Comedy, Musical, Romance              8.30
# Crime, Drama, Sci-Fi                  8.30
# Drama, Family, Sport                  8.25
# Drama, Family                         8.23
# Action, Adventure, Fantasy            8.20
# Action, Comedy, Romance               8.20
# Comedy, Music, Romance                8.20
# Drama, Fantasy, History               8.20
# Adventure, Drama, War                 8.20
# Drama, Fantasy, War                   8.20
# Action, Drama, Sport                  8.20
# Action, Adventure                     8.18
# ...

# %%
# Assuming you want to filter based on the count of occurrences of 'Genre'
df10 = df.groupby('Genre').filter(lambda x: len(x) > 15)

df10
# Out:
#                                         Series_Title Released_Year  Runtime  \
# 0                           The Shawshank Redemption          1994  142 min
# 1                                      The Godfather          1972  175 min
# 2                                    The Dark Knight          2008  152 min
# 3                             The Godfather: Part II          1974  202 min
# 4                                       12 Angry Men          1957   96 min
# 6                                       Pulp Fiction          1994  154 min
# 7                                   Schindler's List          1993  195 min
# 8                                          Inception          2010  148 min
# 9                                         Fight Club          1999  139 min
# 11                                      Forrest Gump          1994  142 min
# 15                                        Goodfellas          1990  146 min
# ...

# %%
df11=df10.groupby('Genre')[['IMDB_Rating']].mean().sort_values(by='IMDB_Rating', ascending=False)
df11
# Out:
#                               IMDB_Rating
# Genre
# Crime, Drama                         8.16
# Biography, Drama, History            8.02
# Drama                                7.98
# Crime, Drama, Mystery                7.97
# Crime, Drama, Thriller               7.95
# Drama, Romance                       7.94
# Action, Adventure, Sci-Fi            7.93
# Animation, Adventure, Comedy         7.92
# Biography, Crime, Drama              7.92
# Action, Crime, Drama                 7.88
# Comedy, Drama, Romance               7.88
# Comedy, Drama                        7.87

# %%
df11.plot()
# Out:
# <Axes: xlabel='Genre'>

# %%
df11.plot.pie(y='IMDB_Rating',figsize=(10,10))
# Out:
# <Axes: ylabel='IMDB_Rating'>

# %%
df
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama         9.30
# 1                Crime, Drama         9.20
# 2        Action, Crime, Drama         9.00
# 3                Crime, Drama         9.00
# 4                Crime, Drama         9.00
# ..                        ...          ...
# ...

# %%
# Grouping by combinations of 'Star1', 'Star2', and 'Star3', calculating mean IMDB_Rating, and sorting
df12 = df.groupby(['Star1', 'Star2', 'Star3'])['IMDB_Rating'].mean().reset_index().sort_values(by='IMDB_Rating', ascending=False)

df12
# Out:
#                  Star1               Star2                 Star3  IMDB_Rating
# 895        Tim Robbins      Morgan Freeman            Bob Gunton         9.30
# 635      Marlon Brando           Al Pacino            James Caan         9.20
# 190     Christian Bale        Heath Ledger         Aaron Eckhart         9.00
# 386        Henry Fonda         Lee J. Cobb         Martin Balsam         9.00
# 26           Al Pacino      Robert De Niro         Robert Duvall         9.00
# ..                 ...                 ...                   ...          ...
# 255  Denzel Washington          Clive Owen          Jodie Foster         7.60
# 628   Marion Cotillard       Sylvie Testud       Pascal Greggory         7.60
# 101       Bill Pullman   Patricia Arquette         John Roselius         7.60
# 625      Maribel Verdú  Gael García Bernal  Daniel Giménez Cacho         7.60
# 496           John Cho       Debra Messing            Joseph Lee         7.60
#
# [993 rows x 4 columns]

# %%
df122=df.groupby('Star1')[['IMDB_Rating']].mean().sort_values(by='IMDB_Rating', ascending=False)
df122
# Out:
#                    IMDB_Rating
# Star1
# Tim Robbins               9.30
# John Travolta             8.90
# Elijah Wood               8.80
# Lilly Wachowski           8.70
# Marlon Brando             8.65
# ...                        ...
# Miki Imai                 7.60
# Mikael Persbrandt         7.60
# Michael Schwartz          7.60
# Michael Beck              7.60
# Jose Coronado             7.60
#
# [660 rows x 1 columns]

# %%
df[df['Star1'].str.contains('Marlon Brando')]
# Out:
#           Series_Title Released_Year  Runtime                   Genre  \
# 1        The Godfather          1972  175 min            Crime, Drama
# 305  On the Waterfront          1954  108 min  Crime, Drama, Thriller
#
#      IMDB_Rating                                           Overview  \
# 1           9.20  An organized crime dynasty's aging patriarch t...
# 305         8.10  An ex-prize fighter turned longshoreman strugg...
#
#     Meta_score              Director          Star1        Star2        Star3  \
# 1       100.00  Francis Ford Coppola  Marlon Brando    Al Pacino   James Caan
# 305      91.00            Elia Kazan  Marlon Brando  Karl Malden  Lee J. Cobb
#
#             Star4  No_of_Votes        Gross
# 1    Diane Keaton      1620367 134966411.00
# 305   Rod Steiger       142107   9600000.00

# %%
df13=df.groupby(['Star1', 'Star2', 'Star3']).agg({'IMDB_Rating': 'mean'})
df13 = df13.sort_values(by='IMDB_Rating', ascending=False)
df13
# Out:
#                                                            IMDB_Rating
# Star1             Star2              Star3
# Tim Robbins       Morgan Freeman     Bob Gunton                   9.30
# Marlon Brando     Al Pacino          James Caan                   9.20
# Christian Bale    Heath Ledger       Aaron Eckhart                9.00
# Henry Fonda       Lee J. Cobb        Martin Balsam                9.00
# Al Pacino         Robert De Niro     Robert Duvall                9.00
# ...                                                                ...
# Denzel Washington Clive Owen         Jodie Foster                 7.60
# Marion Cotillard  Sylvie Testud      Pascal Greggory              7.60
# Bill Pullman      Patricia Arquette  John Roselius                7.60
# Maribel Verdú     Gael García Bernal Daniel Giménez Cacho         7.60
# John Cho          Debra Messing      Joseph Lee                   7.60
#
# [993 rows x 1 columns]
